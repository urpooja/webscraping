# %%
import requests

# %%
import bs4

# %%
res= requests.get('https://www.youtube.com/results?searc+movie+titles+till+2018')

# %%
res.text
# Out:
# '  <!DOCTYPE html><html lang="en" data-cast-api-enabled="true"><head><style name="www-roboto" >@font-face{font-family:\'Roboto\';font-style:italic;font-weight:400;src:local(\'Roboto Italic\'),local(\'Roboto-Italic\'),url(//fonts.gstatic.com/s/roboto/v18/KFOkCnqEu92Fr1Mu51xIIzc.ttf)format(\'truetype\');}@font-face{font-family:\'Roboto\';font-style:normal;font-weight:400;src:local(\'Roboto Regular\'),local(\'Roboto-Regular\'),url(//fonts.gstatic.com/s/roboto/v18/KFOmCnqEu92Fr1Mu4mxP.ttf)format(\'truetype\');}@font-face{font-family:\'Roboto\';font-style:normal;font-weight:500;src:local(\'Roboto Medium\'),local(\'Roboto-Medium\'),url(//fonts.gstatic.com/s/roboto/v18/KFOlCnqEu92Fr1MmEU9fBBc9.ttf)format(\'truetype\');}@font-face{font-family:\'Roboto\';font-style:italic;font-weight:500;src:local(\'Roboto Medium Italic\'),local(\'Roboto-MediumItalic\'),url(//fonts.gstatic.com/s/roboto/v18/KFOjCnqEu92Fr1Mu51S7ACc6CsE.ttf)format(\'truetype\');}</style><script name="www-roboto" >if (document.fo
# ...

# %%
soup = bs4.BeautifulSoup(res.text, 'lxml')

# %%
hey = soup.select('h3')

# %%
hey
# Out:
# [<h3>
#        Best of YouTube
#      </h3>,
#  <h3 class="watch-queue-title">Watch Queue</h3>,
#  <h3 class="tv-queue-title">Queue</h3>,
#  <h3 class="yt-lockup-title "><a aria-describedby="description-id-923208" class="yt-uix-tile-link yt-ui-ellipsis yt-ui-ellipsis-2 yt-uix-sessionlink spf-link " data-sessionlink="itct=CFgQ3DAYACITCMuFza2lydsCFbnCcwEdMSIGcij0JFIgYm9sbHl3b29kIG1vdmllIHRpdGxlcyB0aWxsIDIwMTg" dir="ltr" href="/watch?v=cFsgpZbMrcQ" rel="spf-prefetch" title="Race 3 Official Trailer | Salman Khan | Remo D'Souza | Bollywood Movie 2018 | #Race3ThisEID">Race 3 Official Trailer | Salman Khan | Remo D'Souza | Bollywood Movie 2018 | #Race3ThisEID</a><span class="accessible-description" id="description-id-923208"> - Duration: 3:32.</span></h3>,
# ...

# %%
hey[0].getText()
# Out:
# 'bollywood movie titles till 2018 - YouTube'

# %%
for link in soup.find_all('a'):
    print(link.get('href'))
# Out:
# /
# //www.youtube.com/upload
# /
# /feed/trending
# /feed/history
# /channel/UC-9-kyTW8ZkZNDHQJ6FgpwQ
# /channel/UCEgdi0XIXXZ-qJOFPf4JSKw
# /channel/UCOpNcN46UbXVtpKMrmU4Abg
# /channel/UClgRkhTL3_hImCAmdLfDE4g
# /channel/UCY9Jh3SK0N1SAVJi-U--Rwg
# /channel/UCYfdidRxbB8Qhf0Nx7ioOYw
# /channel/UC4R8DWoMoI7CAwX8_LjQHig
# /channel/UCvScgo6mAvbMEjszK4sSj6g
# /channel/UCzuqhhs6NWbgTzMuM09WKDQ
# /feed/guide_builder
# https://accounts.google.com/ServiceLogin?continue=https%3A%2F%2Fwww.youtube.com%2Fsignin%3Fnext%3D%252Fresults%253Fsearch_query%253Dbollywood%252Bmovie%252Btitles%252Btill%252B2018%26hl%3Den%26feature%3Dsign_in_promo%26app%3Ddesktop%26action_handle_signin%3Dtrue&hl=en&passive=true&service=youtube&uilel=3
# /results?sp=EgIIAQ%253D%253D&search_query=bollywood+movie+titles+till+2018
# /results?sp=EgIIAg%253D%253D&search_query=bollywood+movie+titles+till+2018
# /results?sp=EgIIAw%253D%253D&search_query=bollywood+movie+titles+till+2018
# ...

# %%
len(link.get('href'))
# Out:
# 300

# %%
print(soup.get_text())
# Out:
# @font-face{font-family:'Roboto';font-style:italic;font-weight:400;src:local('Roboto Italic'),local('Roboto-Italic'),url(//fonts.gstatic.com/s/roboto/v18/KFOkCnqEu92Fr1Mu51xIIzc.ttf)format('truetype');}@font-face{font-family:'Roboto';font-style:normal;font-weight:400;src:local('Roboto Regular'),local('Roboto-Regular'),url(//fonts.gstatic.com/s/roboto/v18/KFOmCnqEu92Fr1Mu4mxP.ttf)format('truetype');}@font-face{font-family:'Roboto';font-style:normal;font-weight:500;src:local('Roboto Medium'),local('Roboto-Medium'),url(//fonts.gstatic.com/s/roboto/v18/KFOlCnqEu92Fr1MmEU9fBBc9.ttf)format('truetype');}@font-face{font-family:'Roboto';font-style:italic;font-weight:500;src:local('Roboto Medium Italic'),local('Roboto-MediumItalic'),url(//fonts.gstatic.com/s/roboto/v18/KFOjCnqEu92Fr1Mu51S7ACc6CsE.ttf)format('truetype');}if (document.fonts && document.fonts.load) {document.fonts.load("400 10pt Roboto", "E");document.fonts.load("500 10pt Roboto", "E");}var ytcsi = {gt: function(n) {n = (n || '') 
# ...

# %%
soup.find_all("a")
# Out:
# [<a class="masthead-logo-renderer yt-uix-sessionlink spf-link " data-sessionlink="itct=CAUQsV4iEwjLhc2tpcnbAhW5wnMBHTEiBnIo9CQ" href="/" id="logo-container" title="YouTube Home"> <span class="logo masthead-logo-renderer-logo yt-sprite" title="YouTube Home"></span>
#  <span class="content-region">IN</span></a>,
#  <a class="yt-uix-button yt-uix-sessionlink yt-uix-button-opacity yt-uix-button-size-default yt-uix-button-has-icon yt-uix-tooltip yt-uix-button-empty" data-sessionlink="ei=qzMdW4uEPbmFz7sPscSYkAc&amp;feature=mhsb" href="//www.youtube.com/upload" id="upload-btn" title="Upload"><span class="yt-uix-button-icon-wrapper"><span class="yt-uix-button-icon yt-uix-button-icon-material-upload yt-sprite"></span></span></a>,
# ...

# %%
soup.find_all(id=True)
# Out:
# [<body class=" visibility-logging-enabled ltr exp-invert-logo exp-mouseover-img exp-responsive exp-search-big-thumbs site-center-aligned site-as-giant-card guide-pinning-enabled appbar-hidden not-nirvana-dogfood delayed-frame-styles-not-in " data-spf-name="other" dir="ltr" id="body">
#  <div id="early-body"></div>
#  <div id="body-container"><div id="a11y-announcements-container" role="alert"><div id="a11y-announcements-message"></div></div><form action="/logout" method="POST" name="logoutForm"><input name="action_logout" type="hidden" value="1"/></form><div id="masthead-positioner"> <div id="ticker-content">
#  </div>
#  <div class="clearfix yt-base-gutter" id="yt-masthead-container"> <button class="skip-nav" data-target-id="main" id="a11y-skip-nav" tabindex="3">
#  Skip navigation
#    </button>
# ...

# %%
import urllib.request
htmlfile = urllib.request.urlopen("https://www.youtube.com/results?search_query=bollywood+movie+titles+till+2018")
htmltext = htmlfile.read()
print(htmltext)
# Out:
# b'  <!DOCTYPE html><html lang="en" data-cast-api-enabled="true"><head><style name="www-roboto" >@font-face{font-family:\'Roboto\';font-style:normal;font-weight:400;src:local(\'Roboto Regular\'),local(\'Roboto-Regular\'),url(//fonts.gstatic.com/s/roboto/v18/KFOmCnqEu92Fr1Mu4mxP.ttf)format(\'truetype\');}@font-face{font-family:\'Roboto\';font-style:normal;font-weight:500;src:local(\'Roboto Medium\'),local(\'Roboto-Medium\'),url(//fonts.gstatic.com/s/roboto/v18/KFOlCnqEu92Fr1MmEU9fBBc9.ttf)format(\'truetype\');}@font-face{font-family:\'Roboto\';font-style:italic;font-weight:400;src:local(\'Roboto Italic\'),local(\'Roboto-Italic\'),url(//fonts.gstatic.com/s/roboto/v18/KFOkCnqEu92Fr1Mu51xIIzc.ttf)format(\'truetype\');}@font-face{font-family:\'Roboto\';font-style:italic;font-weight:500;src:local(\'Roboto Medium Italic\'),local(\'Roboto-MediumItalic\'),url(//fonts.gstatic.com/s/roboto/v18/KFOjCnqEu92Fr1Mu51S7ACc6CsE.ttf)format(\'truetype\');}</style><script name="www-roboto" >if (document.f
# ...
